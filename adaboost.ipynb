# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/psat_summer
# Out:
# /content/drive/My Drive/psat_summer

# %%
import pandas as pd
import numpy as np
import os

from sklearn import svm

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, classification_report
from sklearn.ensemble import AdaBoostClassifier

from imblearn.over_sampling import SMOTE

import pickle
import joblib
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
train = pd.read_csv("train_pca.csv")

# %%
y = train['target']
X = train.drop('target', axis = 1)

# %% [markdown]
# 시도 1

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state = 2021)

# %%
smote = SMOTE(random_state = 2021)
smote = smote.fit_sample(X_train, y_train)
smote_x = pd.DataFrame(smote[0])
smote_y = smote[1]
smote_x.columns = X_valid.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
model = AdaBoostClassifier(n_estimators=1000, learning_rate=0.01, random_state=2021)
model.fit(smote_x, smote_y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=0.01,
#                    n_estimators=1000, random_state=2021)

# %%
y_pred = model.predict(valid_x)

# %%
len(y_pred)
# Out:
# 5600

# %%
valid_y
# Out:
# 1        1
# 5        0
# 6        0
# 15       0
# 22       1
#         ..
# 27973    0
# 27985    1
# 27986    0
# 27992    0
# 27997    0
# Name: target, Length: 5600, dtype: int64

# %%
confusion_matrix(valid_y, y_pred)
# Out:
# array([[3922, 1119],
#        [ 136,  423]])

# %%
f1_score(valid_y, y_pred)
# Out:
# 0.40266539742979535

# %%
print(classification_report(valid_y, y_pred, target_names=['class 0', 'class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.97      0.78      0.86      5041
#      class 1       0.27      0.76      0.40       559
#
#     accuracy                           0.78      5600
#    macro avg       0.62      0.77      0.63      5600
# weighted avg       0.90      0.78      0.82      5600

# %% [markdown]
# 시도 2

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state = 2021)

# %%
smote = SMOTE(random_state = 2021)
smote = smote.fit_sample(X_train, y_train)
smote_x = pd.DataFrame(smote[0])
smote_y = smote[1]
smote_x.columns = X_valid.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
model = AdaBoostClassifier(n_estimators=1000, learning_rate=0.001, random_state=2021)
model.fit(smote_x, smote_y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#                    learning_rate=0.001, n_estimators=1000, random_state=2021)

# %%
y_pred = model.predict(valid_x)

# %%
len(y_pred)
# Out:
# 5600

# %%
valid_y
# Out:
# 1        1
# 5        0
# 6        0
# 15       0
# 22       1
#         ..
# 27973    0
# 27985    1
# 27986    0
# 27992    0
# 27997    0
# Name: target, Length: 5600, dtype: int64

# %%
confusion_matrix(valid_y, y_pred)
# Out:
# array([[3892, 1149],
#        [ 134,  425]])

# %%
f1_score(valid_y, y_pred)
# Out:
# 0.3984997655883732

# %%
print(classification_report(valid_y, y_pred, target_names=['class 0', 'class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.97      0.77      0.86      5041
#      class 1       0.27      0.76      0.40       559
#
#     accuracy                           0.77      5600
#    macro avg       0.62      0.77      0.63      5600
# weighted avg       0.90      0.77      0.81      5600

# %% [markdown]
# 시도 3

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state = 2021)

# %%
smote = SMOTE(random_state = 2021)
smote = smote.fit_sample(X_train, y_train)
smote_x = pd.DataFrame(smote[0])
smote_y = smote[1]
smote_x.columns = X_valid.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
model = AdaBoostClassifier(n_estimators=3000, learning_rate=0.01, random_state=2021)
model.fit(smote_x, smote_y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=0.01,
#                    n_estimators=3000, random_state=2021)

# %%
y_pred = model.predict(X_valid)

# %%
len(y_pred)
# Out:
# 8400

# %%
confusion_matrix(y_valid, y_pred)
# Out:
# array([[6171, 1410],
#        [ 251,  568]])

# %%
f1_score(y_valid, y_pred)
# Out:
# 0.406149445834823

# %%
print(classification_report(y_valid, y_pred, target_names=['class 0', 'class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.96      0.81      0.88      7581
#      class 1       0.29      0.69      0.41       819
#
#     accuracy                           0.80      8400
#    macro avg       0.62      0.75      0.64      8400
# weighted avg       0.90      0.80      0.84      8400

# %%
test = pd.read_csv("test_pca.csv")

# %%
test.shape
# Out:
# (2000, 189)

# %%
prediction = model.predict(test) # has only x variables

# %%
submission = pd.DataFrame(columns = ['id', 'target'])
submission['id'] = range(1,2001)

# %%
submission['target'] = prediction

# %%
submission['target'].value_counts()
# Out:
# 0    1511
# 1     489
# Name: target, dtype: int64

# %%
submission.to_csv("adaboost_ver1.csv", header = True, index = False)

# %%
submission
# Out:
#         id  target
# 0        1       0
# 1        2       0
# 2        3       0
# 3        4       0
# 4        5       0
# ...    ...     ...
# 1995  1996       0
# 1996  1997       0
# 1997  1998       0
# 1998  1999       0
# 1999  2000       0
#
# [2000 rows x 2 columns]

# %% [markdown]
# 시도 4

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state = 2021)

# %%
smote = SMOTE(random_state = 2021)
smote = smote.fit_sample(X_train, y_train)
smote_x = pd.DataFrame(smote[0])
smote_y = smote[1]
smote_x.columns = X_valid.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
model = AdaBoostClassifier(n_estimators=600, learning_rate=0.05, random_state=2021)
model.fit(smote_x, smote_y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=0.05,
#                    n_estimators=600, random_state=2021)

# %%
joblib.dump(model, 'AD.pkl')
# Out:
# ['AD.pkl']

# %%
y_pred = model.predict(X_valid)

# %%
len(y_pred)
# Out:
# 8400

# %%
confusion_matrix(y_valid, y_pred)
# Out:
# array([[6170, 1411],
#        [ 251,  568]])

# %%
f1_score(y_valid, y_pred)
# Out:
# 0.40600428877769834

# %%
print(classification_report(y_valid, y_pred, target_names=['class 0', 'class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.96      0.81      0.88      7581
#      class 1       0.29      0.69      0.41       819
#
#     accuracy                           0.80      8400
#    macro avg       0.62      0.75      0.64      8400
# weighted avg       0.90      0.80      0.83      8400

# %%
test = pd.read_csv("test_pca.csv")

# %%
test.shape
# Out:
# (2000, 189)

# %%
prediction = model.predict(test) # has only x variables

# %%
submission = pd.DataFrame(columns = ['id', 'target'])
submission['id'] = range(1,2001)

# %%
submission['target'] = prediction

# %%
submission['target'].value_counts()
# Out:
# 0    1509
# 1     491
# Name: target, dtype: int64

# %%
submission.to_csv("adaboost_ver4.csv", header = True, index = False)

# %% [markdown]
# 시도 5

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state = 2021)

# %%
smote = SMOTE(random_state = 2021)
smote = smote.fit_sample(X_train, y_train)
smote_x = pd.DataFrame(smote[0])
smote_y = smote[1]
smote_x.columns = X_valid.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
model = AdaBoostClassifier(n_estimators=1000, learning_rate=0.05, random_state=2021)
model.fit(smote_x, smote_y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=0.05,
#                    n_estimators=1000, random_state=2021)

# %%
joblib.dump(model, 'AD.pkl')
# Out:
# ['AD.pkl']

# %%
y_pred = model.predict(X_valid)

# %%
len(y_pred)
# Out:
# 8400

# %%
confusion_matrix(y_valid, y_pred)
# Out:
# array([[6311, 1270],
#        [ 276,  543]])

# %%
f1_score(y_valid, y_pred)
# Out:
# 0.4126139817629179

# %%
print(classification_report(y_valid, y_pred, target_names=['class 0', 'class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.96      0.83      0.89      7581
#      class 1       0.30      0.66      0.41       819
#
#     accuracy                           0.82      8400
#    macro avg       0.63      0.75      0.65      8400
# weighted avg       0.89      0.82      0.84      8400

# %%
test = pd.read_csv("test_pca.csv")

# %%
test.shape
# Out:
# (2000, 189)

# %%
prediction = model.predict(test) # has only x variables

# %%
submission = pd.DataFrame(columns = ['id', 'target'])
submission['id'] = range(1,2001)

# %%
submission['target'] = prediction

# %%
submission['target'].value_counts()
# Out:
# 0    1546
# 1     454
# Name: target, dtype: int64

# %%
submission.to_csv("adaboost_ver5.csv", header = True, index = False)
